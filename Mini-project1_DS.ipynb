# %% [markdown]
# ## Scrape Data of the first 30 pages of the website https://www.skinnytaste.com/

# %%
 for link in soup.find_all('a'):
        print(link.get('href'))
#post=[]
for i in range(3):   # number of page +1
    headers = {"Accept-Language": "en-US, en;q=0.5"}
    source=requests.get("https://www.skinnytaste.com/", headers=headers).text
    soup=BeautifulSoup(source, 'lxml')
    #soup.prettify()
    #print(soup.a)
   # print(soup.find("div").findParent())
    #post=soup.find('div', class_='post-title')
     
    post_name=soup.find('div', class_='post-title').h1.text
    print('P=',post_name)
   
    #links = soup.find('figure').find('img', src=True)
    #print(mydivs)
    #post_name=soup.find('div', class_='data-relish-open-tab="recipes"')
     #div_find=bs.find('div')    #print(header)
   # print(div_find)
#    food_name_list=bs.findAll('div', class_='post-title')
#    food_name=food_name_list[0].h1.text
#    food_name=header.find('img')['data-pin-title']
# Out:
# https://www.skinnytaste.com/
# /
# https://www.skinnytaste.com/recipe-index/
# https://www.skinnytaste.com/recipe-index/
# https://www.skinnytaste.com/recipes/appetizers/
# https://www.skinnytaste.com/recipes/breakfast-brunch/
# https://www.skinnytaste.com/recipes/dessert/
# https://www.skinnytaste.com/recipes/drinks/
# https://www.skinnytaste.com/recipes/lunch/
# https://www.skinnytaste.com/recipes/dinner-recipes/
# https://www.skinnytaste.com/recipes/side-dishes/
# https://www.skinnytaste.com/recipes/salad/
# https://www.skinnytaste.com/recipes/snacks/
# https://www.skinnytaste.com/recipes/soup/
# https://www.skinnytaste.com/spiralizer-recipes/
# https://www.skinnytaste.com/main-ingredient/
# https://www.skinnytaste.com/main-ingredient/beef-recipes/
# https://www.skinnytaste.com/main-ingredient/chicken-recipes/
# https://www.skinnytaste.com/main-ingredient/fish-recipes/
# https://www.skinnytaste.com/main-ingredient/grains-and-legume-recipes/
# ...

# %%
 for link in soup.find_all('a'):
        print(link.get('href'))
# Out:
# https://www.skinnytaste.com/
# /
# https://www.skinnytaste.com/recipe-index/
# https://www.skinnytaste.com/recipe-index/
# https://www.skinnytaste.com/recipes/appetizers/
# https://www.skinnytaste.com/recipes/breakfast-brunch/
# https://www.skinnytaste.com/recipes/dessert/
# https://www.skinnytaste.com/recipes/drinks/
# https://www.skinnytaste.com/recipes/lunch/
# https://www.skinnytaste.com/recipes/dinner-recipes/
# https://www.skinnytaste.com/recipes/side-dishes/
# https://www.skinnytaste.com/recipes/salad/
# https://www.skinnytaste.com/recipes/snacks/
# https://www.skinnytaste.com/recipes/soup/
# https://www.skinnytaste.com/spiralizer-recipes/
# https://www.skinnytaste.com/main-ingredient/
# https://www.skinnytaste.com/main-ingredient/beef-recipes/
# https://www.skinnytaste.com/main-ingredient/chicken-recipes/
# https://www.skinnytaste.com/main-ingredient/fish-recipes/
# https://www.skinnytaste.com/main-ingredient/grains-and-legume-recipes/
# ...

# %%
#print(soup.get_text())

# %%
print(soup.find_all('div', class_="post-title"))
# Out:
# [<div class="post-title"><h1><a href="https://www.skinnytaste.com/apple-cranberry-crumble/" rel="bookmark">Apple Cranberry Crumble</a></h1><div class="post-meta"><div class="icons"><span><a href="https://www.skinnytaste.com/recipes/dairy-free/"><noscript><img alt="Dairy Free" class="attachment-thumbnail size-thumbnail" height="60" src="https://www.skinnytaste.com/wp-content/uploads/2019/04/icon-DF.png" width="60"/></noscript><img alt="Dairy Free" class="lazyload attachment-thumbnail size-thumbnail" data-src="https://www.skinnytaste.com/wp-content/uploads/2019/04/icon-DF.png" height="60" src="data:image/svg+xml,%3Csvg%20xmlns=%22http://www.w3.org/2000/svg%22%20viewBox=%220%200%2060%2060%22%3E%3C/svg%3E" width="60"/></a></span><span><a href="https://www.skinnytaste.com/recipes/gluten-free/"><noscript><img alt="Gluten Free" class="attachment-thumbnail size-thumbnail" height="60" src="https://www.skinnytaste.com/wp-content/uploads/2019/04/icon-GF.png" width="60"/></noscript><img alt="Glu
# ...

# %%
for Post in soup.find_all('div', class_='post-title'):
    headline = Post.h1.text
    #print(headline)
    
   # summary = Post.find('div', class_='post-body entry-content').text
    #print(summary)
    
    #video_link= Post.find('iframe')['src']
    #print(video_link)

    print()
    
   # csv_writer.writerow([headline, summary, video_link])

#csv_file.close()
